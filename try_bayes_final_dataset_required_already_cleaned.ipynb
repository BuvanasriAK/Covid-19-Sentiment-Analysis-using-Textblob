# %%
import pandas as pd
tweets=pd.read_csv('Datasets/final_dataset_required.csv')
tweets.head()
# Out:
#                                                 text  sentiment
# 0  chaotic situation puerto ricans indignant tour...          0
# 1          assembly m j rivers death covid 2 workers          1
# 2  piotrradwan1 piotrwjtowicz6 gov pl cancer lect...          1
# 3  driving upturn activity sales business covid 1...          0
# 4  far anti vaxxer tony excuse wanting inject som...          2

# %%
tweets_df = tweets
X=tweets_df['text']
y=tweets_df['sentiment']
tweets_df.shape
# Out:
# (90811, 2)

# %%
X, y
# Out:
# (0        chaotic situation puerto ricans indignant tour...
#  1                assembly m j rivers death covid 2 workers
#  2        piotrradwan1 piotrwjtowicz6 gov pl cancer lect...
#  3        driving upturn activity sales business covid 1...
#  4        far anti vaxxer tony excuse wanting inject som...
#                                 ...
#  90806    tonight received word really good friend mine ...
#  90807    covid re taking several bolsonarista believe c...
#  90808    tragedy tragedy press uncle tested positive co...
#  90809    states tamil nadu punjab postpone cancel board...
#  90810                    looks someone needs covid testing
#  Name: text, Length: 90811, dtype: object,
#  0        0
#  1        1
#  2        1
#  3        0
#  4        2
#          ..
#  90806    2
#  90807    2
#  90808    1
#  90809    0
#  90810    0
#  Name: sentiment, Length: 90811, dtype: int64)

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words=stopwords.words('english')
stemmer=PorterStemmer()

# %%
import re
cleaned_data=[]
for i in range(len(X)):
    tweet=X.iloc[i]
    cleaned_data.append(tweet)

# %%
cleaned_data
# Out:
# ['chaotic situation puerto ricans indignant tourists breaking covid mandates via',
#  'assembly m j rivers death covid 2 workers',
#  'piotrradwan1 piotrwjtowicz6 gov pl cancer lecture unfortunately covid regardless stress movement state health know healthy athletic person unfortunately died quit c',
#  'driving upturn activity sales business covid 19 plus star startups making happen ai startups',
#  'far anti vaxxer tony excuse wanting inject something body little research done regards long term ramifications taking said vaccine ve covid ll let',
#  'ridiculous writes incredibly helpful books fact crib sheet number one resource mom don t agree take kids covid fine stop attacking providing opinion different',
#  'thank cripps full house covid vaccines dashed surgery vaccine shift amp efficient well done amp team',
#  'repairs cases structure covid 19',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=3000,stop_words=['covid19','covid'])
X_fin=cv.fit_transform(tweets_df['text'].values.astype('U')).toarray()

# %%
sentiment_ordering = [1, 0, 2]
y = y.apply(lambda x: sentiment_ordering.index(x))

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_fin,y,test_size=0.3)
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model.predict(X_test)
from sklearn.metrics import classification_report
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78      8973
#            1       0.81      0.65      0.72      7291
#            2       0.75      0.85      0.79     10980
#
#     accuracy                           0.77     27244
#    macro avg       0.78      0.76      0.77     27244
# weighted avg       0.78      0.77      0.77     27244
